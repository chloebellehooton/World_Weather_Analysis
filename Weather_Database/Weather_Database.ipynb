# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 4. Get the nearest city using the citipy module.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# 5. Perform an API call with the OpenWeatherMap.
# 6. Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | te anau
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | komsomolskiy
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | lere
# Processing Record 10 of Set 1 | north bend
# Processing Record 11 of Set 1 | ha noi
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | tay ninh
# Processing Record 15 of Set 1 | grand gaube
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | gimli
# Processing Record 19 of Set 1 | bathsheba
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | katsina
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | eureka
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | khani
# Processing Record 32 of Set 1 | springbok
# Processing Record 33 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | surt
# Processing Record 37 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | flinders
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | abbeville
# Processing Record 45 of Set 1 | wawa
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | port hawkesbury
# Processing Record 48 of Set 1 | hede
# Processing Record 49 of Set 1 | vianopolis
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | pangody
# Processing Record 3 of Set 2 | verkhoyansk
# Processing Record 4 of Set 2 | kodinsk
# Processing Record 5 of Set 2 | kaeo
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | kameshkovo
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | morro agudo
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | caranavi
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | anchorage
# Processing Record 17 of Set 2 | verkhnedneprovskiy
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | kalabo
# Processing Record 20 of Set 2 | port lincoln
# Processing Record 21 of Set 2 | suluq
# Processing Record 22 of Set 2 | tsurib
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | vanimo
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | san quintin
# Processing Record 29 of Set 2 | tura
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | muisne
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | carauari
# Processing Record 38 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | alice springs
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | tezu
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | moron
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 49 of Set 2 | puerto escondido
# Processing Record 50 of Set 2 | acarau
# Processing Record 1 of Set 3 | hvolsvollur
# Processing Record 2 of Set 3 | tigil
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | ucluelet
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | lovozero
# Processing Record 7 of Set 3 | hokitika
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | lazo
# Processing Record 11 of Set 3 | tabalosos
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | sola
# Processing Record 14 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 3 | makakilo city
# Processing Record 16 of Set 3 | iskilip
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | bambanglipuro
# Processing Record 20 of Set 3 | flin flon
# Processing Record 21 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 3 | honiara
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | berlevag
# Processing Record 27 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 3 | cseteny
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | acapulco
# Processing Record 35 of Set 3 | marsa matruh
# Processing Record 36 of Set 3 | quang ngai
# Processing Record 37 of Set 3 | netishyn
# Processing Record 38 of Set 3 | ust-kuyga
# Processing Record 39 of Set 3 | inongo
# Processing Record 40 of Set 3 | namatanai
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | sisimiut
# Processing Record 46 of Set 3 | chino valley
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | mildura
# Processing Record 49 of Set 3 | touros
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | channel-port aux basques
# Processing Record 2 of Set 4 | san fernando
# Processing Record 3 of Set 4 | kieta
# Processing Record 4 of Set 4 | cabedelo
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | bonavista
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | sao felix do xingu
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | santarem
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | rudbar
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | sao joao da barra
# Processing Record 17 of Set 4 | sibiti
# Processing Record 18 of Set 4 | akyab
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | emirdag
# Processing Record 22 of Set 4 | port hedland
# Processing Record 23 of Set 4 | kalengwa
# Processing Record 24 of Set 4 | iberia
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | pindobacu
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | mangaluru
# Processing Record 29 of Set 4 | antalaha
# Processing Record 30 of Set 4 | klyuchi
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | hastings
# Processing Record 33 of Set 4 | naryan-mar
# Processing Record 34 of Set 4 | puerto quijarro
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | pleshanovo
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | amahai
# Processing Record 39 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 40 of Set 4 | bairiki
# Processing Record 41 of Set 4 | beipiao
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | kiunga
# Processing Record 45 of Set 4 | sawtell
# Processing Record 46 of Set 4 | eskisehir
# Processing Record 47 of Set 4 | bichura
# Processing Record 48 of Set 4 | rawson
# Processing Record 49 of Set 4 | coolum beach
# Processing Record 50 of Set 4 | taoudenni
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | mathbaria
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | mendoza
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | saint-augustin
# Processing Record 9 of Set 5 | mahebourg
# Processing Record 10 of Set 5 | zhicheng
# Processing Record 11 of Set 5 | urgut
# Processing Record 12 of Set 5 | shingu
# Processing Record 13 of Set 5 | avanigadda
# Processing Record 14 of Set 5 | centralia
# Processing Record 15 of Set 5 | tilichiki
# Processing Record 16 of Set 5 | arman
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | samarai
# Processing Record 19 of Set 5 | khandyga
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | mogadishu
# Processing Record 25 of Set 5 | goderich
# Processing Record 26 of Set 5 | bell ville
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | kupang
# Processing Record 29 of Set 5 | sao filipe
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | maumere
# Processing Record 32 of Set 5 | roebourne
# Processing Record 33 of Set 5 | santiago del estero
# Processing Record 34 of Set 5 | agva
# City not found. Skipping...
# Processing Record 35 of Set 5 | grindavik
# Processing Record 36 of Set 5 | portree
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | khatanga
# Processing Record 39 of Set 5 | bombay
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | baboua
# City not found. Skipping...
# Processing Record 43 of Set 5 | rayagada
# Processing Record 44 of Set 5 | golden
# Processing Record 45 of Set 5 | coihaique
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 5 | haikou
# Processing Record 49 of Set 5 | hofn
# Processing Record 50 of Set 5 | uniontown
# Processing Record 1 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 6 | kasongo-lunda
# Processing Record 3 of Set 6 | adrar
# Processing Record 4 of Set 6 | pahrump
# Processing Record 5 of Set 6 | sakaiminato
# Processing Record 6 of Set 6 | olafsvik
# Processing Record 7 of Set 6 | anzhero-sudzhensk
# Processing Record 8 of Set 6 | kulhudhuffushi
# Processing Record 9 of Set 6 | yarmouth
# Processing Record 10 of Set 6 | santa rosa
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | krasnoarmeysk
# Processing Record 13 of Set 6 | voh
# Processing Record 14 of Set 6 | poyarkovo
# Processing Record 15 of Set 6 | kang
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | maragogi
# Processing Record 18 of Set 6 | rush
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | port blair
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | lagunas
# Processing Record 23 of Set 6 | dingzhou
# Processing Record 24 of Set 6 | gorontalo
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | golden gate
# Processing Record 27 of Set 6 | malinyi
# Processing Record 28 of Set 6 | aneho
# Processing Record 29 of Set 6 | sungaipenuh
# Processing Record 30 of Set 6 | calama
# Processing Record 31 of Set 6 | tecoanapa
# Processing Record 32 of Set 6 | dandong
# Processing Record 33 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | nome
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | zhezkazgan
# Processing Record 37 of Set 6 | cravo norte
# Processing Record 38 of Set 6 | mattru
# Processing Record 39 of Set 6 | faya
# Processing Record 40 of Set 6 | lavrentiya
# Processing Record 41 of Set 6 | kauhajoki
# Processing Record 42 of Set 6 | nha trang
# Processing Record 43 of Set 6 | soyo
# Processing Record 44 of Set 6 | qiryat ono
# Processing Record 45 of Set 6 | nemuro
# Processing Record 46 of Set 6 | waipawa
# Processing Record 47 of Set 6 | codrington
# Processing Record 48 of Set 6 | napier
# Processing Record 49 of Set 6 | inirida
# Processing Record 50 of Set 6 | fare
# Processing Record 1 of Set 7 | inhambane
# Processing Record 2 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 7 | tateyama
# Processing Record 4 of Set 7 | bhavnagar
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | sembe
# Processing Record 7 of Set 7 | arona
# Processing Record 8 of Set 7 | caravelas
# Processing Record 9 of Set 7 | tsybli
# Processing Record 10 of Set 7 | ust-koksa
# Processing Record 11 of Set 7 | eyrarbakki
# Processing Record 12 of Set 7 | nanortalik
# Processing Record 13 of Set 7 | ambilobe
# Processing Record 14 of Set 7 | moryakovskiy zaton
# Processing Record 15 of Set 7 | le port
# Processing Record 16 of Set 7 | sorland
# Processing Record 17 of Set 7 | waingapu
# Processing Record 18 of Set 7 | praia
# Processing Record 19 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | alanya
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | okato
# Processing Record 24 of Set 7 | severo-kurilsk
# Processing Record 25 of Set 7 | santa cruz de tenerife
# Processing Record 26 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 27 of Set 7 | basmat
# Processing Record 28 of Set 7 | kiama
# Processing Record 29 of Set 7 | juneau
# Processing Record 30 of Set 7 | callaway
# Processing Record 31 of Set 7 | bandar-e lengeh
# Processing Record 32 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 7 | xining
# Processing Record 34 of Set 7 | bud
# Processing Record 35 of Set 7 | wuhu
# Processing Record 36 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 7 | havoysund
# Processing Record 38 of Set 7 | villefontaine
# Processing Record 39 of Set 7 | filingue
# Processing Record 40 of Set 7 | luau
# Processing Record 41 of Set 7 | areka
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | magadan
# Processing Record 44 of Set 7 | talcahuano
# Processing Record 45 of Set 7 | almaznyy
# Processing Record 46 of Set 7 | waitati
# Processing Record 47 of Set 7 | vestmannaeyjar
# Processing Record 48 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 7 | tucson
# Processing Record 50 of Set 7 | vostok
# Processing Record 1 of Set 8 | zonguldak
# Processing Record 2 of Set 8 | waddan
# Processing Record 3 of Set 8 | jaguaruana
# Processing Record 4 of Set 8 | nyaunglebin
# Processing Record 5 of Set 8 | tautira
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | cestas
# Processing Record 8 of Set 8 | sao jose da coroa grande
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | mufumbwe
# Processing Record 12 of Set 8 | baijiantan
# Processing Record 13 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | saskylakh
# Processing Record 15 of Set 8 | zarubino
# Processing Record 16 of Set 8 | lasa
# Processing Record 17 of Set 8 | brigantine
# Processing Record 18 of Set 8 | urumqi
# Processing Record 19 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 8 | calbiga
# Processing Record 21 of Set 8 | maimon
# City not found. Skipping...
# Processing Record 22 of Set 8 | chernukha
# Processing Record 23 of Set 8 | avera
# Processing Record 24 of Set 8 | bakchar
# Processing Record 25 of Set 8 | dudinka
# Processing Record 26 of Set 8 | nanakuli
# Processing Record 27 of Set 8 | evensk
# Processing Record 28 of Set 8 | jawhar
# Processing Record 29 of Set 8 | shelby
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | smithers
# Processing Record 32 of Set 8 | costa rica
# Processing Record 33 of Set 8 | coihueco
# Processing Record 34 of Set 8 | talnakh
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | watertown
# Processing Record 37 of Set 8 | buala
# Processing Record 38 of Set 8 | isehara
# Processing Record 39 of Set 8 | takoradi
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | senneterre
# Processing Record 42 of Set 8 | oranjestad
# Processing Record 43 of Set 8 | sur
# Processing Record 44 of Set 8 | edeia
# Processing Record 45 of Set 8 | payo
# Processing Record 46 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 8 | chapais
# Processing Record 48 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | torbay
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | bakal
# Processing Record 2 of Set 9 | jacksonville
# Processing Record 3 of Set 9 | arrecife
# Processing Record 4 of Set 9 | lahaina
# Processing Record 5 of Set 9 | gigmoto
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | kennett
# Processing Record 9 of Set 9 | port maria
# Processing Record 10 of Set 9 | provideniya
# Processing Record 11 of Set 9 | college
# Processing Record 12 of Set 9 | kayseri
# Processing Record 13 of Set 9 | jiayuguan
# Processing Record 14 of Set 9 | aykhal
# Processing Record 15 of Set 9 | ampanihy
# Processing Record 16 of Set 9 | kilindoni
# Processing Record 17 of Set 9 | springfield
# Processing Record 18 of Set 9 | harper
# Processing Record 19 of Set 9 | srednekolymsk
# Processing Record 20 of Set 9 | mulanje
# Processing Record 21 of Set 9 | khon kaen
# Processing Record 22 of Set 9 | klaksvik
# Processing Record 23 of Set 9 | novobirilyussy
# Processing Record 24 of Set 9 | port hardy
# Processing Record 25 of Set 9 | norman wells
# Processing Record 26 of Set 9 | erenhot
# Processing Record 27 of Set 9 | poum
# Processing Record 28 of Set 9 | brae
# Processing Record 29 of Set 9 | stroud
# Processing Record 30 of Set 9 | sydney
# Processing Record 31 of Set 9 | colotlan
# Processing Record 32 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 9 | ugoofaaru
# Processing Record 34 of Set 9 | sambava
# Processing Record 35 of Set 9 | isla mujeres
# Processing Record 36 of Set 9 | baghdad
# Processing Record 37 of Set 9 | teruel
# Processing Record 38 of Set 9 | akonolinga
# Processing Record 39 of Set 9 | kikwit
# Processing Record 40 of Set 9 | majene
# Processing Record 41 of Set 9 | latehar
# Processing Record 42 of Set 9 | ambon
# Processing Record 43 of Set 9 | veraval
# Processing Record 44 of Set 9 | shelburne
# Processing Record 45 of Set 9 | sobolevo
# Processing Record 46 of Set 9 | merrill
# Processing Record 47 of Set 9 | surdulica
# Processing Record 48 of Set 9 | puerto penasco
# Processing Record 49 of Set 9 | riyadh
# Processing Record 50 of Set 9 | porto velho
# Processing Record 1 of Set 10 | omboue
# Processing Record 2 of Set 10 | mayo
# Processing Record 3 of Set 10 | mount isa
# Processing Record 4 of Set 10 | geraldton
# Processing Record 5 of Set 10 | lensk
# Processing Record 6 of Set 10 | buckingham
# Processing Record 7 of Set 10 | banatski karlovac
# Processing Record 8 of Set 10 | porbandar
# Processing Record 9 of Set 10 | norton shores
# Processing Record 10 of Set 10 | mahanoro
# Processing Record 11 of Set 10 | atherton
# Processing Record 12 of Set 10 | del rio
# Processing Record 13 of Set 10 | saint anthony
# Processing Record 14 of Set 10 | abha
# Processing Record 15 of Set 10 | phonhong
# Processing Record 16 of Set 10 | kaka
# Processing Record 17 of Set 10 | kiruna
# Processing Record 18 of Set 10 | panino
# Processing Record 19 of Set 10 | chinhoyi
# Processing Record 20 of Set 10 | hasaki
# Processing Record 21 of Set 10 | norden
# Processing Record 22 of Set 10 | uk
# City not found. Skipping...
# Processing Record 23 of Set 10 | la union
# Processing Record 24 of Set 10 | chirongui
# Processing Record 25 of Set 10 | general roca
# Processing Record 26 of Set 10 | zavitinsk
# Processing Record 27 of Set 10 | noumea
# Processing Record 28 of Set 10 | tonantins
# Processing Record 29 of Set 10 | arlit
# Processing Record 30 of Set 10 | asau
# Processing Record 31 of Set 10 | mao
# Processing Record 32 of Set 10 | kijang
# Processing Record 33 of Set 10 | pringsewu
# Processing Record 34 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 35 of Set 10 | dunayivtsi
# City not found. Skipping...
# Processing Record 36 of Set 10 | villarrica
# Processing Record 37 of Set 10 | rio de janeiro
# Processing Record 38 of Set 10 | teya
# Processing Record 39 of Set 10 | mehran
# Processing Record 40 of Set 10 | kamina
# Processing Record 41 of Set 10 | dubbo
# Processing Record 42 of Set 10 | koungou
# Processing Record 43 of Set 10 | oostburg
# Processing Record 44 of Set 10 | jian
# Processing Record 45 of Set 10 | toktogul
# Processing Record 46 of Set 10 | alta floresta
# Processing Record 47 of Set 10 | svejbaek
# Processing Record 48 of Set 10 | bintulu
# Processing Record 49 of Set 10 | saint-jovite
# Processing Record 50 of Set 10 | nacala
# Processing Record 1 of Set 11 | jiwani
# Processing Record 2 of Set 11 | saint-raymond
# Processing Record 3 of Set 11 | heihe
# Processing Record 4 of Set 11 | gboko
# Processing Record 5 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 6 of Set 11 | coelho neto
# Processing Record 7 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 11 | slave lake
# Processing Record 9 of Set 11 | lindi
# Processing Record 10 of Set 11 | youkounkoun
# Processing Record 11 of Set 11 | katima mulilo
# Processing Record 12 of Set 11 | upata
# Processing Record 13 of Set 11 | coos bay
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | chulman
# Processing Record 16 of Set 11 | krasnoarmeyskoye
# Processing Record 17 of Set 11 | narrabri
# Processing Record 18 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 11 | camacupa
# Processing Record 20 of Set 11 | salinas
# Processing Record 21 of Set 11 | kishtwar
# Processing Record 22 of Set 11 | dalvik
# Processing Record 23 of Set 11 | cucuta
# Processing Record 24 of Set 11 | mitsamiouli
# Processing Record 25 of Set 11 | sinnamary
# Processing Record 26 of Set 11 | rio verde de mato grosso
# Processing Record 27 of Set 11 | sheltozero
# Processing Record 28 of Set 11 | padang
# Processing Record 29 of Set 11 | camopi
# Processing Record 30 of Set 11 | belaya gora
# Processing Record 31 of Set 11 | rudsar
# Processing Record 32 of Set 11 | balaipungut
# Processing Record 33 of Set 11 | starosubkhangulovo
# Processing Record 34 of Set 11 | trairi
# Processing Record 35 of Set 11 | palaikastron
# Processing Record 36 of Set 11 | cervo
# Processing Record 37 of Set 11 | sumbe
# Processing Record 38 of Set 11 | bluefields
# Processing Record 39 of Set 11 | bonthe
# Processing Record 40 of Set 11 | sembakung
# Processing Record 41 of Set 11 | prince rupert
# Processing Record 42 of Set 11 | denpasar
# Processing Record 43 of Set 11 | margate
# Processing Record 44 of Set 11 | dharchula
# Processing Record 45 of Set 11 | teguldet
# Processing Record 46 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 11 | barkot
# Processing Record 48 of Set 11 | aripuana
# Processing Record 49 of Set 11 | kudahuvadhoo
# Processing Record 50 of Set 11 | muyezerskiy
# Processing Record 1 of Set 12 | pergine valsugana
# Processing Record 2 of Set 12 | portland
# Processing Record 3 of Set 12 | vigrestad
# Processing Record 4 of Set 12 | gondanglegi
# Processing Record 5 of Set 12 | columbus
# Processing Record 6 of Set 12 | yenagoa
# Processing Record 7 of Set 12 | orapa
# Processing Record 8 of Set 12 | high level
# Processing Record 9 of Set 12 | yurga
# Processing Record 10 of Set 12 | cascais
# Processing Record 11 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 12 | umm lajj
# Processing Record 13 of Set 12 | vammala
# Processing Record 14 of Set 12 | skibbereen
# Processing Record 15 of Set 12 | sao miguel
# Processing Record 16 of Set 12 | nalchiti
# Processing Record 17 of Set 12 | svolvaer
# Processing Record 18 of Set 12 | homer
# Processing Record 19 of Set 12 | whitehaven
# Processing Record 20 of Set 12 | lazaro cardenas
# Processing Record 21 of Set 12 | seoul
# Processing Record 22 of Set 12 | ziway
# Processing Record 23 of Set 12 | riberalta
# Processing Record 24 of Set 12 | tailai
# Processing Record 25 of Set 12 | alihe
# Processing Record 26 of Set 12 | mabaruma
# Processing Record 27 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 12 | hamamatsu
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | maningrida
# Processing Record 31 of Set 12 | maniwaki
# Processing Record 32 of Set 12 | ribeira brava
# Processing Record 33 of Set 12 | port shepstone
# Processing Record 34 of Set 12 | brownsville
# Processing Record 35 of Set 12 | gogrial
# Processing Record 36 of Set 12 | assiniboia
# Processing Record 37 of Set 12 | shangqiu
# Processing Record 38 of Set 12 | raudeberg
# Processing Record 39 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 12 | semporna
# Processing Record 41 of Set 12 | awbari
# Processing Record 42 of Set 12 | tokur
# Processing Record 43 of Set 12 | nkhotakota
# Processing Record 44 of Set 12 | matameye
# City not found. Skipping...
# Processing Record 45 of Set 12 | bahir dar
# Processing Record 46 of Set 12 | cockburn town
# Processing Record 47 of Set 12 | mae sot
# Processing Record 48 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 12 | pandamatenga
# Processing Record 50 of Set 12 | preobrazheniye
# Processing Record 1 of Set 13 | burica
# City not found. Skipping...
# Processing Record 2 of Set 13 | strezhevoy
# Processing Record 3 of Set 13 | pangkalanbuun
# Processing Record 4 of Set 13 | kruisfontein
# Processing Record 5 of Set 13 | tahe
# Processing Record 6 of Set 13 | amboasary
# Processing Record 7 of Set 13 | marawi
# Processing Record 8 of Set 13 | jinxiang
# Processing Record 9 of Set 13 | bar harbor
# Processing Record 10 of Set 13 | san policarpo
# Processing Record 11 of Set 13 | finschhafen
# Processing Record 12 of Set 13 | borogontsy
# Processing Record 13 of Set 13 | severnoye
# Processing Record 14 of Set 13 | williston
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | maceio
# Processing Record 17 of Set 13 | coquimbo
# Processing Record 18 of Set 13 | hualmay
# Processing Record 19 of Set 13 | requena
# Processing Record 20 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 13 | baragua
# Processing Record 22 of Set 13 | manokwari
# Processing Record 23 of Set 13 | biak
# Processing Record 24 of Set 13 | mattawa
# Processing Record 25 of Set 13 | sabang
# Processing Record 26 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 28 of Set 13 | hovd
# Processing Record 29 of Set 13 | mayumba
# Processing Record 30 of Set 13 | changji
# Processing Record 31 of Set 13 | udachnyy
# Processing Record 32 of Set 13 | narsingi
# Processing Record 33 of Set 13 | carnot
# Processing Record 34 of Set 13 | guiyang
# Processing Record 35 of Set 13 | tocopilla
# Processing Record 36 of Set 13 | opuwo
# Processing Record 37 of Set 13 | ketchikan
# Processing Record 38 of Set 13 | ilulissat
# Processing Record 39 of Set 13 | batsfjord
# Processing Record 40 of Set 13 | inndyr
# Processing Record 41 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 13 | kaitong
# Processing Record 43 of Set 13 | balilihan
# Processing Record 44 of Set 13 | ouesso
# Processing Record 45 of Set 13 | zyryanka
# Processing Record 46 of Set 13 | teahupoo
# Processing Record 47 of Set 13 | matalom
# Processing Record 48 of Set 13 | skjervoy
# Processing Record 49 of Set 13 | chipinge
# Processing Record 50 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 14 | vidalia
# Processing Record 2 of Set 14 | ayan
# Processing Record 3 of Set 14 | moose factory
# Processing Record 4 of Set 14 | mogok
# Processing Record 5 of Set 14 | anshun
# Processing Record 6 of Set 14 | tuatapere
# Processing Record 7 of Set 14 | bozoum
# Processing Record 8 of Set 14 | bage
# Processing Record 9 of Set 14 | alofi
# Processing Record 10 of Set 14 | tuy hoa
# Processing Record 11 of Set 14 | karratha
# Processing Record 12 of Set 14 | mazagao
# Processing Record 13 of Set 14 | charters towers
# Processing Record 14 of Set 14 | tarakan
# Processing Record 15 of Set 14 | olinda
# Processing Record 16 of Set 14 | maloy
# Processing Record 17 of Set 14 | baturaja
# Processing Record 18 of Set 14 | nikki
# Processing Record 19 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 20 of Set 14 | vitim
# Processing Record 21 of Set 14 | vilyuysk
# Processing Record 22 of Set 14 | thai binh
# Processing Record 23 of Set 14 | la orilla
# Processing Record 24 of Set 14 | ilebo
# Processing Record 25 of Set 14 | lagos
# Processing Record 26 of Set 14 | iquitos
# Processing Record 27 of Set 14 | mega
# Processing Record 28 of Set 14 | mecca
# Processing Record 29 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 14 | seddon
# Processing Record 31 of Set 14 | matagami
# Processing Record 32 of Set 14 | ahuimanu
# Processing Record 33 of Set 14 | rosarito
# Processing Record 34 of Set 14 | luba
# Processing Record 35 of Set 14 | kisangani
# Processing Record 36 of Set 14 | mayahi
# Processing Record 37 of Set 14 | bazarnyy karabulak
# Processing Record 38 of Set 14 | isangel
# Processing Record 39 of Set 14 | along
# Processing Record 40 of Set 14 | beyneu
# Processing Record 41 of Set 14 | sesori
# Processing Record 42 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 14 | langfang
# Processing Record 44 of Set 14 | tomatlan
# Processing Record 45 of Set 14 | serra talhada
# Processing Record 46 of Set 14 | hervey bay
# Processing Record 47 of Set 14 | khanewal
# Processing Record 48 of Set 14 | guangyuan
# Processing Record 49 of Set 14 | abapo
# Processing Record 50 of Set 14 | sosua
# Processing Record 1 of Set 15 | kavaratti
# Processing Record 2 of Set 15 | muli
# Processing Record 3 of Set 15 | mankachar
# Processing Record 4 of Set 15 | santo antonio do ica
# Processing Record 5 of Set 15 | angoche
# Processing Record 6 of Set 15 | saginaw
# Processing Record 7 of Set 15 | san jose
# Processing Record 8 of Set 15 | omsukchan
# Processing Record 9 of Set 15 | alenquer
# Processing Record 10 of Set 15 | itoman
# Processing Record 11 of Set 15 | yar-sale
# Processing Record 12 of Set 15 | riverton
# Processing Record 13 of Set 15 | auki
# Processing Record 14 of Set 15 | kumylzhenskaya
# Processing Record 15 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 16 of Set 15 | sao miguel do araguaia
# Processing Record 17 of Set 15 | bodden town
# Processing Record 18 of Set 15 | west norriton
# Processing Record 19 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 15 | kota belud
# Processing Record 21 of Set 15 | douglas
# Processing Record 22 of Set 15 | awjilah
# Processing Record 23 of Set 15 | rio gallegos
# Processing Record 24 of Set 15 | okha
# Processing Record 25 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 15 | salinopolis
# Processing Record 27 of Set 15 | doka
# Processing Record 28 of Set 15 | poya
# Processing Record 29 of Set 15 | camapua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder columns
city_data_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[city_data_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown      US  42.0970  -79.2353     71.02        93          90
# 1        Rikitea      PF -23.1203 -134.9692     73.51        71          36
# 2      Hithadhoo      MV  -0.6000   73.0833     82.38        73          11
# 3  Mount Gambier      AU -37.8333  140.7667     53.51        87          40
# 4        Te Anau      NZ -45.4167  167.7167     46.24        94         100
# 5   Komsomolskiy      UZ  40.4272   71.7189     90.32        25          10
# 6         Hobart      AU -42.8794  147.3294     51.03        92          75
# 7           Lere      NG  10.3870    8.5726     73.96        82          88
# 8     North Bend      US  43.4065 -124.2243     57.24        87          90
# 9         Ha Noi      VN  21.0245  105.8412     95.00        53          55
#
#    Wind Speed Current Description
# 0        4.00     overcast clouds
# 1       11.45    scattered clouds
# 2        5.48          few clouds
# 3        8.05    scattered clouds
# 4        4.79     overcast clouds
# 5        6.91           clear sky
# 6        0.00       broken clouds
# 7        4.88     overcast clouds
# 8       17.27     overcast clouds
# 9       12.93       broken clouds

# %%
# 8. Export the DataFrame as a CSV file and save to the folder
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
